# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Gemini model integration

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0.0
)
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.6.2', 'langchain': '1.4.0', 'langchain-google-genai': '4.3.1'}}, profile={'name': 'Gemini 3.6 Flash', 'release_date': '2026-07-21', 'last_updated': '2026-07-21', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'medium'}, google_api_key=SecretStr('**********'), model='gemini-3.6-flash', temperature=0.0, client=<google.genai.client.Client object at 0x7b9cec624ec0>, default_metadata=(), model_kwargs={})

# %%
response = model.invoke("Hello How are you?")
response.content
# Out:
# /home/soham/Desktop/Practice/langchainPractice/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:3120: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text',
#   'text': "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?",
#   'extras': {'signature': '...'}}]

# %%
gemini_model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = gemini_model.invoke("Why do parrots talk?")
response.content
# Out:
# [{'type': 'text',
#   'text': 'Parrots talk because of a fascinating combination of **anatomy, social behavior, and high intelligence**. Unlike most animals, which make innate sounds based on instinct, parrots learn to vocalize much like humans do—by listening, remembering, and practicing. \n\nHere is a breakdown of why parrots talk:\n\n### 1. Social Integration (The Flock Mentality)\nIn the wild, parrots are intensely social birds that live in large flocks. To survive, individuals must fit in. They do this by mimicking the calls of their family and flock members. \n* By sounding like the rest of the flock, a parrot strengthens social bonds, identifies family members, and maintains group cohesion.\n* When a parrot lives in a human home, **humans become its flock**. To integrate into this "human flock," the parrot mimics human speech.\n\n### 2. High Intelligence and Brain Structure\nParrots have exceptionally large brains relative to their body size, specifically a forebrain region that is heavily involved in vocal learning. \n* They have a specialized neural circuit called the **song system**, which is normally only found in songbirds, hummingbirds, and humans. This system allows them to hear a sound, process it, and replicate it.\n* Some parrots (most famously an African Grey named Alex studied by Dr. Irene Pepperberg) don\'t just mimic—they actually understand the meaning of the words they use to communicate requests, colors, and shapes.\n\n### 3. Anatomical Adaptations (The Syrinx)\nParrots have the physical hardware to make human-like sounds. While humans use a larynx, vocal cords, and lips to speak, birds use an organ called the **syrinx**, located at the base of their windpipe. By changing the shape of their syrinx and using their tongue and beak to shape the airflow, they can reproduce a vast range of sounds—from human words and microwaves to barking dogs and creaking doors.\n\n### 4. Attention, Boredom, and Reward\nDomestic parrots quickly figure out that talking gets a reaction. \n* If a parrot says "Hello!" or "Want a cracker?" and a human immediately looks at them, talks back, or gives them a treat, the parrot learns that **talking is a powerful tool to get attention or food**.\n* Parrots are also prone to boredom. Talking can be a form of self-stimulation or entertainment when they are left alone.\n\n### Summary\nIn short, parrots don\'t talk because they understand human language the way we do (with some rare, intelligent exceptions); they talk because **mimicry is their natural way of connecting with their social group**, and humans make very interesting flock members!',
#   'extras': {'signature': 'El4KXAERTTIP+NYrkTN7AnrG7Kb7xfaWmJznE/nnzS7fJ4QNVOOQMlLCggdtJWyQx3zgY/NxowiPxTHNrumZ8L9uGBcw6jK/gFl1JyBraxxDLkL+/J+1GJY2NGhIXmgz'}}]

# %% [markdown]
# ### Groq model integration

# %%
model = init_chat_model("groq:openai/gpt-oss-20b")
response = model.invoke("What is the capital of France?")
response.content
# Out:
# 'The capital of France is **Paris**.'

# %%
from langchain_groq import ChatGroq
model = ChatGroq(
    model="openai/gpt-oss-20b")
response = model.invoke("What is the capital of Gujarat?")
response.content
# Out:
# 'The capital of Gujarat is **Gandhinagar**.'
